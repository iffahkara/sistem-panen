# %% [markdown]
# <a href="https://colab.research.google.com/github/iffahkara/sistem-panen/blob/main/program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def total_panen(jumlah, harga):
    return jumlah * harga

total = total_panen(10, 5000)
print("Total hasil panen: Rp", total)
# Out:
# Total hasil panen: Rp 50000
